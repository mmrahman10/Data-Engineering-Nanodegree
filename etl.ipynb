# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
song_files = get_files("./data/song_data")
song_files[0:4]
# Out:
# ['/home/workspace/data/song_data/A/A/A/TRAAAAW128F429D538.json',
#  '/home/workspace/data/song_data/A/A/A/TRAAAVG12903CFA543.json',
#  '/home/workspace/data/song_data/A/A/A/TRAAARJ128F9320760.json',
#  '/home/workspace/data/song_data/A/A/A/TRAAAPK128E0786D96.json']

# %%
filepath = song_files[19]
filepath
# Out:
# '/home/workspace/data/song_data/A/A/B/TRAABXG128F9318EBD.json'

# %%
df = pd.read_json(filepath, typ='series')
df.head(10)
# Out:
# num_songs                            1
# artist_id           ARNPAGP1241B9C7FD4
# artist_latitude                   None
# artist_longitude                  None
# artist_location
# artist_name                  lextrical
# song_id             SOZVMJI12AB01808AF
# title                  Synthetic Dream
# duration                       165.694
# year                                 0
# dtype: object

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
song_data = df[["song_id", "title", "artist_id", "year", "duration"]]
song_data = list(song_data.values)
song_data
# Out:
# ['SOZVMJI12AB01808AF', 'Synthetic Dream', 'ARNPAGP1241B9C7FD4', 0, 165.69424]

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
cur.execute(song_table_insert, song_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
artist_data = df[["artist_id", "artist_name", "artist_location", "artist_latitude", "artist_longitude"]]
artist_data
# Out:
# artist_id           ARNPAGP1241B9C7FD4
# artist_name                  lextrical
# artist_location
# artist_latitude                   None
# artist_longitude                  None
# dtype: object

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
cur.execute(artist_table_insert, artist_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
log_files = get_files("./data/log_data")
log_files
# Out:
# ['/home/workspace/data/log_data/2018/11/2018-11-30-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-11-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-23-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-24-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-25-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-20-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-15-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-01-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-03-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-13-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-10-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-28-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-26-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-04-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-14-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-27-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-21-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-06-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-22-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-12-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-05-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-09-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-08-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-02-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-18-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-07-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-16-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-29-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-19-events.json',
#  '/home/workspace/data/log_data/2018/11/2018-11-17-events.json']

# %%
filepath = log_files[19]
filepath
# Out:
# '/home/workspace/data/log_data/2018/11/2018-11-12-events.json'

# %%
df=pd.read_json(filepath, lines=True)
df.head(20)
# Out:
#                                                artist       auth   firstName  \
# 0                                                None  Logged In     Celeste
# 1                                            Pavement  Logged In      Sylvie
# 2   Barry Tuckwell/Academy of St Martin-in-the-Fie...  Logged In     Celeste
# 3                                          Gary Allan  Logged In     Celeste
# 4                                                None  Logged In  Jacqueline
# 5                                  Charttraxx Karaoke  Logged In     Celeste
# 6                                      The Libertines  Logged In  Jacqueline
# 7                             Huey Lewis And The News  Logged In  Jacqueline
# 8                             JOSEF LOCKE & ORCHESTRA  Logged In  Jacqueline
# 9                                               Train  Logged In  Jacqueline
# 10                                        Blind Pilot  Logged In  Jacqueline
# 11                                            Anjulie  Logged In  Jacqueline
# 12                                  59 Times the Pain  Logged In      Jordan
# 13                                               None  Logged In      Kimber
# 14                                               None  Logged In        Lily
# 15                                               None  Logged In        Lily
# 16                                               None  Logged In       Chloe
# 17                                               None  Logged In        Ryan
# 18                                         Pork Dukes  Logged In        Noah
# 19                                               None  Logged In       Adler
#
#    gender  itemInSession   lastName     length level  \
# 0       F              0   Williams        NaN  free
# 1       F              0       Cruz   99.16036  free
# 2       F              1   Williams  277.15873  free
# 3       F              2   Williams  211.22567  free
# 4       F              0      Lynch        NaN  paid
# 5       F              3   Williams  225.17506  free
# 6       F              1      Lynch  179.53914  paid
# 7       F              2      Lynch  245.52444  paid
# 8       F              3      Lynch  166.26893  paid
# 9       F              4      Lynch  216.76363  paid
# 10      F              5      Lynch  156.94322  paid
# 11      F              6      Lynch  194.63791  paid
# 12      F              0  Rodriguez  144.95302  free
# 13      F              0     Norris        NaN  free
# 14      F              0      Burns        NaN  free
# 15      F              1      Burns        NaN  free
# 16      F              0     Cuevas        NaN  free
# 17      M              0      Smith        NaN  free
# 18      M              0     Chavez  133.04118  free
# 19      M              0    Barrera        NaN  free
#
#                                         location method      page  \
# 0                              Klamath Falls, OR    GET      Home
# 1   Washington-Arlington-Alexandria, DC-VA-MD-WV    PUT  NextSong
# 2                              Klamath Falls, OR    PUT  NextSong
# 3                              Klamath Falls, OR    PUT  NextSong
# 4              Atlanta-Sandy Springs-Roswell, GA    GET      Home
# 5                              Klamath Falls, OR    PUT  NextSong
# 6              Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong
# 7              Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong
# 8              Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong
# 9              Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong
# 10             Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong
# 11             Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong
# 12            Los Angeles-Long Beach-Anaheim, CA    PUT  NextSong
# 13         New York-Newark-Jersey City, NY-NJ-PA    GET      Home
# 14         New York-Newark-Jersey City, NY-NJ-PA    GET     About
# 15         New York-Newark-Jersey City, NY-NJ-PA    GET      Home
# 16             San Francisco-Oakland-Hayward, CA    GET      Home
# 17            San Jose-Sunnyvale-Santa Clara, CA    GET      Home
# 18                          Ogden-Clearfield, UT    PUT  NextSong
# 19         New York-Newark-Jersey City, NY-NJ-PA    GET      Home
#
#     registration  sessionId  \
# 0   1.541078e+12        438
# 1   1.540266e+12        345
# 2   1.541078e+12        438
# 3   1.541078e+12        438
# 4   1.540224e+12        389
# 5   1.541078e+12        438
# 6   1.540224e+12        389
# 7   1.540224e+12        389
# 8   1.540224e+12        389
# 9   1.540224e+12        389
# 10  1.540224e+12        389
# 11  1.540224e+12        389
# 12  1.540993e+12        136
# 13  1.540976e+12        412
# 14  1.540621e+12        466
# 15  1.540621e+12        466
# 16  1.540941e+12        470
# 17  1.541017e+12        483
# 18  1.540971e+12        262
# 19  1.540836e+12        428
#
#                                                  song  status             ts  \
# 0                                                None     200  1541990217796
# 1                                Mercy:The Laundromat     200  1541990258796
# 2   Horn Concerto No. 4 in E flat K495: II. Romanc...     200  1541990264796
# 3                            Nothing On But The Radio     200  1541990541796
# 4                                                None     200  1541990714796
# 5                                           Fireflies     200  1541990752796
# 6                                   The Good Old Days     200  1541990842796
# 7                                    Hip To Be Square     200  1541991021796
# 8   How Can You Buy Killarney (1992 Digital Remaster)     200  1541991266796
# 9                                    Hey_ Soul Sister     200  1541991432796
# 10                                    I Buried a Bone     200  1541991648796
# 11                                               Boom     200  1541991804796
# 12                                         Found Home     200  1541993788796
# 13                                               None     200  1542000167796
# 14                                               None     200  1542001320796
# 15                                               None     200  1542001337796
# 16                                               None     200  1542001991796
# 17                                               None     200  1542002972796
# 18                                       Bend & Flush     200  1542003207796
# 19                                               None     200  1542012631796
#
#                                             userAgent userId
# 0   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 1   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     10
# 2   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 3   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 4   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     29
# 5   "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 6   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     29
# 7   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     29
# 8   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     29
# 9   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     29
# 10  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     29
# 11  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     29
# 12  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...     68
# 13  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     47
# 14  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     32
# 15  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     32
# 16  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...     49
# 17  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 18  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) G...     94
# 19  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...    100

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
df["ts"] = pd.to_datetime(df["ts"], unit='ms')
df.head(20)
# Out:
#                                                artist       auth   firstName  \
# 0                                                None  Logged In     Celeste
# 1                                            Pavement  Logged In      Sylvie
# 2   Barry Tuckwell/Academy of St Martin-in-the-Fie...  Logged In     Celeste
# 3                                          Gary Allan  Logged In     Celeste
# 4                                                None  Logged In  Jacqueline
# 5                                  Charttraxx Karaoke  Logged In     Celeste
# 6                                      The Libertines  Logged In  Jacqueline
# 7                             Huey Lewis And The News  Logged In  Jacqueline
# 8                             JOSEF LOCKE & ORCHESTRA  Logged In  Jacqueline
# 9                                               Train  Logged In  Jacqueline
# 10                                        Blind Pilot  Logged In  Jacqueline
# 11                                            Anjulie  Logged In  Jacqueline
# 12                                  59 Times the Pain  Logged In      Jordan
# 13                                               None  Logged In      Kimber
# 14                                               None  Logged In        Lily
# 15                                               None  Logged In        Lily
# 16                                               None  Logged In       Chloe
# 17                                               None  Logged In        Ryan
# 18                                         Pork Dukes  Logged In        Noah
# 19                                               None  Logged In       Adler
#
#    gender  itemInSession   lastName     length level  \
# 0       F              0   Williams        NaN  free
# 1       F              0       Cruz   99.16036  free
# 2       F              1   Williams  277.15873  free
# 3       F              2   Williams  211.22567  free
# 4       F              0      Lynch        NaN  paid
# 5       F              3   Williams  225.17506  free
# 6       F              1      Lynch  179.53914  paid
# 7       F              2      Lynch  245.52444  paid
# 8       F              3      Lynch  166.26893  paid
# 9       F              4      Lynch  216.76363  paid
# 10      F              5      Lynch  156.94322  paid
# 11      F              6      Lynch  194.63791  paid
# 12      F              0  Rodriguez  144.95302  free
# 13      F              0     Norris        NaN  free
# 14      F              0      Burns        NaN  free
# 15      F              1      Burns        NaN  free
# 16      F              0     Cuevas        NaN  free
# 17      M              0      Smith        NaN  free
# 18      M              0     Chavez  133.04118  free
# 19      M              0    Barrera        NaN  free
#
#                                         location method      page  \
# 0                              Klamath Falls, OR    GET      Home
# 1   Washington-Arlington-Alexandria, DC-VA-MD-WV    PUT  NextSong
# 2                              Klamath Falls, OR    PUT  NextSong
# 3                              Klamath Falls, OR    PUT  NextSong
# 4              Atlanta-Sandy Springs-Roswell, GA    GET      Home
# 5                              Klamath Falls, OR    PUT  NextSong
# 6              Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong
# 7              Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong
# 8              Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong
# 9              Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong
# 10             Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong
# 11             Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong
# 12            Los Angeles-Long Beach-Anaheim, CA    PUT  NextSong
# 13         New York-Newark-Jersey City, NY-NJ-PA    GET      Home
# 14         New York-Newark-Jersey City, NY-NJ-PA    GET     About
# 15         New York-Newark-Jersey City, NY-NJ-PA    GET      Home
# 16             San Francisco-Oakland-Hayward, CA    GET      Home
# 17            San Jose-Sunnyvale-Santa Clara, CA    GET      Home
# 18                          Ogden-Clearfield, UT    PUT  NextSong
# 19         New York-Newark-Jersey City, NY-NJ-PA    GET      Home
#
#     registration  sessionId  \
# 0   1.541078e+12        438
# 1   1.540266e+12        345
# 2   1.541078e+12        438
# 3   1.541078e+12        438
# 4   1.540224e+12        389
# 5   1.541078e+12        438
# 6   1.540224e+12        389
# 7   1.540224e+12        389
# 8   1.540224e+12        389
# 9   1.540224e+12        389
# 10  1.540224e+12        389
# 11  1.540224e+12        389
# 12  1.540993e+12        136
# 13  1.540976e+12        412
# 14  1.540621e+12        466
# 15  1.540621e+12        466
# 16  1.540941e+12        470
# 17  1.541017e+12        483
# 18  1.540971e+12        262
# 19  1.540836e+12        428
#
#                                                  song  status  \
# 0                                                None     200
# 1                                Mercy:The Laundromat     200
# 2   Horn Concerto No. 4 in E flat K495: II. Romanc...     200
# 3                            Nothing On But The Radio     200
# 4                                                None     200
# 5                                           Fireflies     200
# 6                                   The Good Old Days     200
# 7                                    Hip To Be Square     200
# 8   How Can You Buy Killarney (1992 Digital Remaster)     200
# 9                                    Hey_ Soul Sister     200
# 10                                    I Buried a Bone     200
# 11                                               Boom     200
# 12                                         Found Home     200
# 13                                               None     200
# 14                                               None     200
# 15                                               None     200
# 16                                               None     200
# 17                                               None     200
# 18                                       Bend & Flush     200
# 19                                               None     200
#
#                         ts                                          userAgent  \
# 0  2018-11-12 02:36:57.796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 1  2018-11-12 02:37:38.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 2  2018-11-12 02:37:44.796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 3  2018-11-12 02:42:21.796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 4  2018-11-12 02:45:14.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 5  2018-11-12 02:45:52.796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 6  2018-11-12 02:47:22.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 7  2018-11-12 02:50:21.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 8  2018-11-12 02:54:26.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 9  2018-11-12 02:57:12.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 10 2018-11-12 03:00:48.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 11 2018-11-12 03:03:24.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 12 2018-11-12 03:36:28.796  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...
# 13 2018-11-12 05:22:47.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 14 2018-11-12 05:42:00.796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 15 2018-11-12 05:42:17.796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 16 2018-11-12 05:53:11.796  Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...
# 17 2018-11-12 06:09:32.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 18 2018-11-12 06:13:27.796  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) G...
# 19 2018-11-12 08:50:31.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
#
#    userId
# 0      53
# 1      10
# 2      53
# 3      53
# 4      29
# 5      53
# 6      29
# 7      29
# 8      29
# 9      29
# 10     29
# 11     29
# 12     68
# 13     47
# 14     32
# 15     32
# 16     49
# 17     26
# 18     94
# 19    100

# %%
df_filter = df[df['page']=='NextSong']
df_filter
# Out:
#                                                 artist       auth   firstName  \
# 1                                             Pavement  Logged In      Sylvie
# 2    Barry Tuckwell/Academy of St Martin-in-the-Fie...  Logged In     Celeste
# 3                                           Gary Allan  Logged In     Celeste
# 5                                   Charttraxx Karaoke  Logged In     Celeste
# 6                                       The Libertines  Logged In  Jacqueline
# 7                              Huey Lewis And The News  Logged In  Jacqueline
# 8                              JOSEF LOCKE & ORCHESTRA  Logged In  Jacqueline
# 9                                                Train  Logged In  Jacqueline
# 10                                         Blind Pilot  Logged In  Jacqueline
# 11                                             Anjulie  Logged In  Jacqueline
# 12                                   59 Times the Pain  Logged In      Jordan
# 18                                          Pork Dukes  Logged In        Noah
# 20                                              Plan B  Logged In       Adler
# 21           Rell featuring Dert_ Killa Klump_ Silence  Logged In       Adler
# 22                                                K-OS  Logged In       Adler
# 23                                     Vanessa Carlton  Logged In       Adler
# 24                                              Camila  Logged In       Emily
# 25                                         Buju Banton  Logged In       Emily
# 27                                               Feist  Logged In      Evelin
# 28                                       Kings Of Leon  Logged In       Chloe
# 29                                                Beck  Logged In       Aiden
# 30                 Big Walter Horton's Blues Harp Band  Logged In       Aiden
# 31                                         Supervielle  Logged In       Aiden
# 32                                         Bryan Adams  Logged In      Samuel
# 33                                            Slipknot  Logged In       Aiden
# 34                                      The Black Keys  Logged In       Aiden
# 35                                           Shinedown  Logged In      Jordan
# 36                                      Devin Townsend  Logged In       Kevin
# 40                                          Stray Cats  Logged In        Ryan
# 42                                       Dwight Yoakam  Logged In        Ryan
# ..                                                 ...        ...         ...
# 178                           California Swag District  Logged In       Emily
# 180                                         Jami Smith  Logged In      Austin
# 181                                      Stephen Lynch  Logged In       Emily
# 182                 Major Organ And The Adding Machine  Logged In       Emily
# 183                                Alejandro Fernandez  Logged In      Austin
# 184                                    Fania All Stars  Logged In       Emily
# 185                                        Livvi Franc  Logged In      Austin
# 186                                  The Lonely Island  Logged In       Emily
# 187                                         Pixie Lott  Logged In       Emily
# 188                                        Donna Lewis  Logged In      Austin
# 189                                           Godsmack  Logged In       Emily
# 190                                           Kid Cudi  Logged In      Austin
# 191                                         Faith Hill  Logged In       Emily
# 192                                           Coldplay  Logged In       Emily
# 193                                        Blind Melon  Logged In       Tegan
# 194                                           BjÃÂ¶rk  Logged In       Tegan
# 196                                              49ers  Logged In       Tegan
# 197                                       Taylor Swift  Logged In       Tegan
# 198                                Sneaky Sound System  Logged In       Tegan
# 200                                           Copeland  Logged In      Jordan
# 201                                              Foals  Logged In       Tegan
# 202                                          PJ Harvey  Logged In       Tegan
# 203                                          Goldfrapp  Logged In       Tegan
# 204                                         Symphony X  Logged In       Tegan
# 205                                             Fisher  Logged In       Tegan
# 206                                        Pencey Prep  Logged In       Tegan
# 207                                           Clear Vu  Logged In       Tegan
# 208                                          Radiohead  Logged In       Tegan
# 209                              The Mamas & The Papas  Logged In       Tegan
# 210                                       Deepest Blue  Logged In       Tegan
#
#     gender  itemInSession   lastName     length level  \
# 1        F              0       Cruz   99.16036  free
# 2        F              1   Williams  277.15873  free
# 3        F              2   Williams  211.22567  free
# 5        F              3   Williams  225.17506  free
# 6        F              1      Lynch  179.53914  paid
# 7        F              2      Lynch  245.52444  paid
# 8        F              3      Lynch  166.26893  paid
# 9        F              4      Lynch  216.76363  paid
# 10       F              5      Lynch  156.94322  paid
# 11       F              6      Lynch  194.63791  paid
# 12       F              0  Rodriguez  144.95302  free
# 18       M              0     Chavez  133.04118  free
# 20       M              1    Barrera  254.95465  free
# 21       M              2    Barrera  223.97342  free
# 22       M              3    Barrera  211.33016  free
# 23       M              4    Barrera  272.40444  free
# 24       F              0     Benson  280.34567  paid
# 25       F              1     Benson  232.48934  paid
# 27       F              0      Ayala  184.94649  free
# 28       F              1     Cuevas  201.79546  free
# 29       M              0       Hess  228.80608  free
# 30       M              1       Hess  210.78159  free
# 31       M              2       Hess  263.83628  free
# 32       M              0   Gonzalez  254.79791  free
# 33       M              3       Hess  259.44771  free
# 34       M              4       Hess  139.51955  free
# 35       F              0      Hicks  233.97832  free
# 36       M              0   Arellano  576.33914  free
# 40       M              0      Smith  243.77424  free
# 42       M              1      Smith  239.30730  free
# ..     ...            ...        ...        ...   ...
# 178      F              5     Benson  239.17669  paid
# 180      M              2    Rosales  243.80036  free
# 181      F              6     Benson   52.81914  paid
# 182      F              7     Benson  129.77587  paid
# 183      M              3    Rosales  177.21424  free
# 184      F              8     Benson  350.09261  paid
# 185      M              4    Rosales  380.99546  free
# 186      F              9     Benson  106.78812  paid
# 187      F             10     Benson  182.33424  paid
# 188      M              5    Rosales  240.95302  free
# 189      F             11     Benson  249.96526  paid
# 190      M              6    Rosales  227.34322  free
# 191      F             12     Benson  222.30159  paid
# 192      F             13     Benson  307.51302  paid
# 193      F              0     Levine  221.90975  paid
# 194      F              1     Levine  348.57751  paid
# 196      F              3     Levine  216.68526  paid
# 197      F              4     Levine  238.99383  paid
# 198      F              5     Levine  243.01669  paid
# 200      F              0  Rodriguez  279.32689  free
# 201      F              7     Levine  281.18159  paid
# 202      F              8     Levine  245.75955  paid
# 203      F              9     Levine  251.14077  paid
# 204      F             10     Levine  436.03546  paid
# 205      F             11     Levine  133.98159  paid
# 206      F             12     Levine  160.88771  paid
# 207      F             13     Levine  210.57261  paid
# 208      F             14     Levine  237.21751  paid
# 209      F             15     Levine  190.58893  paid
# 210      F             16     Levine  210.54649  paid
#
#                                          location method      page  \
# 1    Washington-Arlington-Alexandria, DC-VA-MD-WV    PUT  NextSong
# 2                               Klamath Falls, OR    PUT  NextSong
# 3                               Klamath Falls, OR    PUT  NextSong
# 5                               Klamath Falls, OR    PUT  NextSong
# 6               Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong
# 7               Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong
# 8               Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong
# 9               Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong
# 10              Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong
# 11              Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong
# 12             Los Angeles-Long Beach-Anaheim, CA    PUT  NextSong
# 18                           Ogden-Clearfield, UT    PUT  NextSong
# 20          New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 21          New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 22          New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 23          New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 24                 Augusta-Richmond County, GA-SC    PUT  NextSong
# 25                 Augusta-Richmond County, GA-SC    PUT  NextSong
# 27              Milwaukee-Waukesha-West Allis, WI    PUT  NextSong
# 28              San Francisco-Oakland-Hayward, CA    PUT  NextSong
# 29                      La Crosse-Onalaska, WI-MN    PUT  NextSong
# 30                      La Crosse-Onalaska, WI-MN    PUT  NextSong
# 31                      La Crosse-Onalaska, WI-MN    PUT  NextSong
# 32           Houston-The Woodlands-Sugar Land, TX    PUT  NextSong
# 33                      La Crosse-Onalaska, WI-MN    PUT  NextSong
# 34                      La Crosse-Onalaska, WI-MN    PUT  NextSong
# 35                                    Salinas, CA    PUT  NextSong
# 36                        Harrisburg-Carlisle, PA    PUT  NextSong
# 40             San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
# 42             San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
# ..                                            ...    ...       ...
# 178                Augusta-Richmond County, GA-SC    PUT  NextSong
# 180         New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 181                Augusta-Richmond County, GA-SC    PUT  NextSong
# 182                Augusta-Richmond County, GA-SC    PUT  NextSong
# 183         New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 184                Augusta-Richmond County, GA-SC    PUT  NextSong
# 185         New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 186                Augusta-Richmond County, GA-SC    PUT  NextSong
# 187                Augusta-Richmond County, GA-SC    PUT  NextSong
# 188         New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 189                Augusta-Richmond County, GA-SC    PUT  NextSong
# 190         New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong
# 191                Augusta-Richmond County, GA-SC    PUT  NextSong
# 192                Augusta-Richmond County, GA-SC    PUT  NextSong
# 193                   Portland-South Portland, ME    PUT  NextSong
# 194                   Portland-South Portland, ME    PUT  NextSong
# 196                   Portland-South Portland, ME    PUT  NextSong
# 197                   Portland-South Portland, ME    PUT  NextSong
# 198                   Portland-South Portland, ME    PUT  NextSong
# 200            Los Angeles-Long Beach-Anaheim, CA    PUT  NextSong
# 201                   Portland-South Portland, ME    PUT  NextSong
# 202                   Portland-South Portland, ME    PUT  NextSong
# 203                   Portland-South Portland, ME    PUT  NextSong
# 204                   Portland-South Portland, ME    PUT  NextSong
# 205                   Portland-South Portland, ME    PUT  NextSong
# 206                   Portland-South Portland, ME    PUT  NextSong
# 207                   Portland-South Portland, ME    PUT  NextSong
# 208                   Portland-South Portland, ME    PUT  NextSong
# 209                   Portland-South Portland, ME    PUT  NextSong
# 210                   Portland-South Portland, ME    PUT  NextSong
#
#      registration  sessionId  \
# 1    1.540266e+12        345
# 2    1.541078e+12        438
# 3    1.541078e+12        438
# 5    1.541078e+12        438
# 6    1.540224e+12        389
# 7    1.540224e+12        389
# 8    1.540224e+12        389
# 9    1.540224e+12        389
# 10   1.540224e+12        389
# 11   1.540224e+12        389
# 12   1.540993e+12        136
# 18   1.540971e+12        262
# 20   1.540836e+12        428
# 21   1.540836e+12        428
# 22   1.540836e+12        428
# 23   1.540836e+12        428
# 24   1.540907e+12        377
# 25   1.540907e+12        377
# 27   1.541008e+12        318
# 28   1.540941e+12        490
# 29   1.540829e+12        344
# 30   1.540829e+12        344
# 31   1.540829e+12        344
# 32   1.540493e+12        454
# 33   1.540829e+12        344
# 34   1.540829e+12        344
# 35   1.540009e+12        449
# 36   1.540007e+12        450
# 40   1.541017e+12        491
# 42   1.541017e+12        491
# ..            ...        ...
# 178  1.540907e+12        494
# 180  1.541060e+12        371
# 181  1.540907e+12        494
# 182  1.540907e+12        494
# 183  1.541060e+12        371
# 184  1.540907e+12        494
# 185  1.541060e+12        371
# 186  1.540907e+12        494
# 187  1.540907e+12        494
# 188  1.541060e+12        371
# 189  1.540907e+12        494
# 190  1.541060e+12        371
# 191  1.540907e+12        494
# 192  1.540907e+12        494
# 193  1.540794e+12        481
# 194  1.540794e+12        481
# 196  1.540794e+12        481
# 197  1.540794e+12        481
# 198  1.540794e+12        481
# 200  1.540993e+12        487
# 201  1.540794e+12        481
# 202  1.540794e+12        481
# 203  1.540794e+12        481
# 204  1.540794e+12        481
# 205  1.540794e+12        481
# 206  1.540794e+12        481
# 207  1.540794e+12        481
# 208  1.540794e+12        481
# 209  1.540794e+12        481
# 210  1.540794e+12        481
#
#                                                   song  status  \
# 1                                 Mercy:The Laundromat     200
# 2    Horn Concerto No. 4 in E flat K495: II. Romanc...     200
# 3                             Nothing On But The Radio     200
# 5                                            Fireflies     200
# 6                                    The Good Old Days     200
# 7                                     Hip To Be Square     200
# 8    How Can You Buy Killarney (1992 Digital Remaster)     200
# 9                                     Hey_ Soul Sister     200
# 10                                     I Buried a Bone     200
# 11                                                Boom     200
# 12                                          Found Home     200
# 18                                        Bend & Flush     200
# 20                             Traded In My Cigarettes     200
# 21                                     Talk Is Drastik     200
# 22                                        EMCEE Murdah     200
# 23                                         Come Undone     200
# 24                                               De Mi     200
# 25                                         Cry No More     200
# 27                                      My Moon My Man     200
# 28                                             Revelry     200
# 29                                          Lost Cause     200
# 30                                   Rockin' My Boogie     200
# 31                                                 332     200
# 32                                   Cloud Number Nine     200
# 33              Eyeless (Live version) (Album Version)     200
# 34                                    I'll Be Your Man     200
# 35                    Sound Of Madness (Album Version)     200
# 36                                           Earth Day     200
# 40                                Jeanie Jeanie Jeanie     200
# 42                                      You're The One     200
# ..                                                 ...     ...
# 178                             Teach Me How To Dougie     200
# 180                                               Home     200
# 181  What If That Guy From Smashing Pumpkins Lost H...     200
# 182  Water Dripping On Bread Makes Bread Taste Not ...     200
# 183                                            Matalas     200
# 184                                           Ublabadu     200
# 185                                          Automatik     200
# 186                                        Like A Boss     200
# 187                     Boys And Girls (Album Version)     200
# 188           I Love You Always Forever ( LP Version )     200
# 189                                 Saints And Sinners     200
# 190                                       Up Up & Away     200
# 191                    There You'll Be (Album Version)     200
# 192                                             Clocks     200
# 193                                             Change     200
# 194                                               Undo     200
# 196                                           Touch Me     200
# 197                                        Cold As You     200
# 198                                                UFO     200
# 200        The Day I Lost My Voice (The Suitcase Song)     200
# 201                                   Two Steps_ Twice     200
# 202                                       Naked Cousin     200
# 203                                              Train     200
# 204                                   Absinthe And Rue     200
# 205                                             Rianna     200
# 206                                     PS Don't Write     200
# 207                                            I Adore     200
# 208                                            15 Step     200
# 209                         Dream A Little Dream Of Me     200
# 210                                       Deepest Blue     200
#
#                          ts  \
# 1   2018-11-12 02:37:38.796
# 2   2018-11-12 02:37:44.796
# 3   2018-11-12 02:42:21.796
# 5   2018-11-12 02:45:52.796
# 6   2018-11-12 02:47:22.796
# 7   2018-11-12 02:50:21.796
# 8   2018-11-12 02:54:26.796
# 9   2018-11-12 02:57:12.796
# 10  2018-11-12 03:00:48.796
# 11  2018-11-12 03:03:24.796
# 12  2018-11-12 03:36:28.796
# 18  2018-11-12 06:13:27.796
# 20  2018-11-12 08:50:44.796
# 21  2018-11-12 08:54:58.796
# 22  2018-11-12 08:58:41.796
# 23  2018-11-12 09:02:12.796
# 24  2018-11-12 09:03:03.796
# 25  2018-11-12 09:07:43.796
# 27  2018-11-12 10:18:43.796
# 28  2018-11-12 10:21:13.796
# 29  2018-11-12 10:26:06.796
# 30  2018-11-12 10:29:54.796
# 31  2018-11-12 10:33:24.796
# 32  2018-11-12 10:35:02.796
# 33  2018-11-12 10:37:47.796
# 34  2018-11-12 10:42:06.796
# 35  2018-11-12 11:19:48.796
# 36  2018-11-12 11:41:09.796
# 40  2018-11-12 11:41:22.796
# 42  2018-11-12 11:45:25.796
# ..                      ...
# 178 2018-11-12 21:03:22.796
# 180 2018-11-12 21:04:41.796
# 181 2018-11-12 21:07:21.796
# 182 2018-11-12 21:08:13.796
# 183 2018-11-12 21:08:44.796
# 184 2018-11-12 21:10:22.796
# 185 2018-11-12 21:11:41.796
# 186 2018-11-12 21:16:12.796
# 187 2018-11-12 21:17:58.796
# 188 2018-11-12 21:18:01.796
# 189 2018-11-12 21:21:00.796
# 190 2018-11-12 21:22:01.796
# 191 2018-11-12 21:25:09.796
# 192 2018-11-12 21:28:51.796
# 193 2018-11-12 22:00:04.796
# 194 2018-11-12 22:03:45.796
# 196 2018-11-12 22:22:22.796
# 197 2018-11-12 22:25:58.796
# 198 2018-11-12 22:29:56.796
# 200 2018-11-12 22:41:56.796
# 201 2018-11-12 22:45:06.796
# 202 2018-11-12 22:49:47.796
# 203 2018-11-12 22:53:52.796
# 204 2018-11-12 22:58:03.796
# 205 2018-11-12 23:05:19.796
# 206 2018-11-12 23:07:32.796
# 207 2018-11-12 23:10:12.796
# 208 2018-11-12 23:13:42.796
# 209 2018-11-12 23:17:39.796
# 210 2018-11-12 23:20:49.796
#
#                                              userAgent userId
# 1    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     10
# 2    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 3    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 5    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...     53
# 6    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     29
# 7    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     29
# 8    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     29
# 9    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     29
# 10   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     29
# 11   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     29
# 12   Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...     68
# 18   Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) G...     94
# 20   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...    100
# 21   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...    100
# 22   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...    100
# 23   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...    100
# 24   "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     58
# 25   "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     58
# 27   Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...     34
# 28   Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20...     49
# 29   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     86
# 30   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     86
# 31   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     86
# 32   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     61
# 33   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     86
# 34   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     86
# 35   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     37
# 36   "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     66
# 40   "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 42   "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# ..                                                 ...    ...
# 178  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     58
# 180  Mozilla/5.0 (Windows NT 6.1; rv:31.0) Gecko/20...     12
# 181  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     58
# 182  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     58
# 183  Mozilla/5.0 (Windows NT 6.1; rv:31.0) Gecko/20...     12
# 184  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     58
# 185  Mozilla/5.0 (Windows NT 6.1; rv:31.0) Gecko/20...     12
# 186  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     58
# 187  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     58
# 188  Mozilla/5.0 (Windows NT 6.1; rv:31.0) Gecko/20...     12
# 189  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     58
# 190  Mozilla/5.0 (Windows NT 6.1; rv:31.0) Gecko/20...     12
# 191  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     58
# 192  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...     58
# 193  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 194  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 196  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 197  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 198  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 200  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:31.0) G...     68
# 201  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 202  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 203  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 204  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 205  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 206  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 207  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 208  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 209  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
# 210  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...     80
#
# [166 rows x 18 columns]

# %%
t = df["ts"]
t.head()
# Out:
# 0   2018-11-12 02:36:57.796
# 1   2018-11-12 02:37:38.796
# 2   2018-11-12 02:37:44.796
# 3   2018-11-12 02:42:21.796
# 4   2018-11-12 02:45:14.796
# Name: ts, dtype: datetime64[ns]

# %%
#  Create a dataframe, time_df, containing the time data for this file by combining column_labels and time_data into a dictionary and converting this into a dataframe
#  timestamp, hour, day, week of year, month, year, and weekday
timestamps = df["ts"].dt.time
hrs = df["ts"].dt.hour
days = df["ts"].dt.day
weeks = df["ts"].dt.week
months = df["ts"].dt.month
years = df["ts"].dt.year
weekdays = df["ts"].dt.weekday
column_labels = ("timestamp", "hour", "day", "week of year", "month", "year", "weekday")
time_data = pd.DataFrame({"timestamp": timestamps, "hour": hrs, "day": days, "week": weeks, "month": months, "year": years, "weekday": weekdays})

# %%
time_df = time_data
time_df.head()
# Out:
#          timestamp  hour  day  week  month  year  weekday
# 0  02:36:57.796000     2   12    46     11  2018        0
# 1  02:37:38.796000     2   12    46     11  2018        0
# 2  02:37:44.796000     2   12    46     11  2018        0
# 3  02:42:21.796000     2   12    46     11  2018        0
# 4  02:45:14.796000     2   12    46     11  2018        0

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():
    cur.execute(time_table_insert, list(row))
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
user_df = df[["userId", "firstName", "lastName", "gender", "level"]]
user_df = user_df.drop_duplicates()
user_df = user_df[user_df["userId"]!=""]
user_df
# Out:
#     userId   firstName   lastName gender level
# 0       53     Celeste   Williams      F  free
# 1       10      Sylvie       Cruz      F  free
# 4       29  Jacqueline      Lynch      F  paid
# 12      68      Jordan  Rodriguez      F  free
# 13      47      Kimber     Norris      F  free
# 14      32        Lily      Burns      F  free
# 16      49       Chloe     Cuevas      F  free
# 17      26        Ryan      Smith      M  free
# 18      94        Noah     Chavez      M  free
# 19     100       Adler    Barrera      M  free
# 24      58       Emily     Benson      F  paid
# 27      34      Evelin      Ayala      F  free
# 29      86       Aiden       Hess      M  free
# 32      61      Samuel   Gonzalez      M  free
# 35      37      Jordan      Hicks      F  free
# 36      66       Kevin   Arellano      M  free
# 49      51        Maia      Burke      F  free
# 69      97        Kate    Harrell      F  paid
# 78      78       Chloe       Roth      F  free
# 86      73       Jacob      Klein      M  paid
# 97      76      Jayden      Duffy      F  free
# 119     33     Bronson     Harris      M  free
# 153     14    Theodore     Harris      M  free
# 175     12      Austin    Rosales      M  free
# 179     63        Ayla    Johnson      F  free
# 193     80       Tegan     Levine      F  paid

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
for i, row in user_df.iterrows():
    cur.execute(user_table_insert, row)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
for index, row in df.iterrows():

    # get songid and artistid from song and artist tables
    cur.execute(song_select, (row.song, row.artist, row.length))
    results = cur.fetchone()
    
    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None

    # insert songplay record
    songplay_data = (row.ts, row.userId, row.level, songid, artistid, row.sessionId, row.location, row.userAgent)
    if row.userId != "":
        cur.execute(songplay_table_insert, songplay_data)
        conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
